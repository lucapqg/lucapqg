# %%
# =============================================== usuals
import pandas as pd
import numpy as np

# =============================================== plot
import seaborn as sns
import matplotlib.pyplot as plt
# ============================================== Images
from PIL import Image
# =============================================== web scraping
import requests
import zipfile

from io import StringIO
from io import  BytesIO

from requests_html import HTMLSession 
from requests_html import AsyncHTMLSession
from datetime import datetime


from time import sleep
from tqdm import tqdm

# ================================================ warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # **Web scraping**

# %%
def weather_series(station,years):
        session = HTMLSession() # Inicializa a classe de Requisicoes HTML
        url = 'https://portal.inmet.gov.br/dadoshistoricos'
        r = session.get(url) # Obtem as requisicoes

        # Pega todos os links de download dos arquivos com os dados climaticos historicos.
        links = [i for i in r.html.find('a') if 'https://portal.inmet.gov.br/uploads/dadoshistoricos' in str(i)]
        # <a href="https://portal.inmet.gov.br/uploads/dadoshistoricos/2001.zip">ANO 2001 (AUTOMÁTICA)</a>

        out = pd.DataFrame()
        for station in station:
            # Bloco que captura e trata os dados presentes em cada link obtido.
                for y in years:

                    url = list(filter(lambda x: str(y) in x.attrs['href'],links))[0].attrs['href'] 
                    a = BytesIO(requests.get(url).content)
                    mzip = zipfile.ZipFile(a)
                    FILE_NAME = [i.filename for i in mzip.infolist() if station in i.filename] # A001 - ESTAÇÃO DE BRASILIA
                    bytes_arq = mzip.open(name = FILE_NAME[0], mode = 'r').read()
                    string_arq = str(bytes_arq,'latin-1')
                    data = StringIO(string_arq) 
                    df_clim=pd.read_csv(data,skiprows = range(0, 8), error_bad_lines=False, encoding='latin-1',sep=';')
                    df_clim = df_clim.loc[:,~df_clim.columns.str.match("Unnamed")]


                    df_clim['Hora UTC'] = df_clim['Hora UTC'].apply(lambda x: x.replace('00 UTC',''))
                    df_clim['index'] = df_clim['Data'].astype(str)+' '+df_clim['Hora UTC'].astype(str)
                    df_clim['index'] = df_clim['index'].apply(lambda x: datetime.strptime(x,'%Y/%m/%d %H'))
                    df_clim.set_index('index',inplace=True)
                    df_clim.drop(['Data','Hora UTC'],axis=1,inplace=True)
                    df_clim = df_clim.apply(lambda x: x.apply(lambda y: str(y).replace(',','.'))) #trocar todas as virgulas por pontos
                    df_clim = df_clim.astype(float)
                
                    df_clim['CÓDIGO_ESTAÇÃO'] = station
                    out = pd.concat([out,df_clim],axis=0,ignore_index=False)
                

        New_Names=['precipitacao',
                   'pressao_instantanea',
                   'pressao_max',
                   'pressao_min',
                   'radiacao',
                   'temperatura_bulbo_seco',
                   'temperatura_orvalho_instantanea',
                   'temperatura_maxima',
                   'temperatura_minima',
                   'temperatura_maxima_orvalho',
                   'temperatura_minima_orvalho',
                   'umidade_relativa_maxima',
                   'umidade_relativa_minima',
                   'umidade_relativa_instantanea',
                    'vento_direcao', 
                    'vento_rajada',
                    'vento_velocidade', 
                    'estacao',
                    'radiacao']

        out.columns = New_Names
        return out

# %%
def print_confusion_matrix(confusion_matrix,class_label,icv,fontsize=8.5):

    fig, ax = plt.subplots(figsize=(5, 5))
    try:
        heatmap = sns.heatmap(confusion_matrix, annot=True, fmt="d", cbar=False, ax=ax,cmap='Spectral')
    except ValueError:
        raise ValueError("Confusion matrix values must be integers.")
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize,fontweight='bold')
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize,fontweight='bold')
    # axes.set_ylabel('True label',fontsize=fontsize)
    # axes.set_xlabel('Predicted label',fontsize=fontsize)
    ax.set_title(f"{class_label}",fontsize=fontsize,fontweight='bold')
    
    fig.savefig(f'//srv-viacor01/pgo/PGOC/PGOCD/Paineis/13 - Machine Learning/Turbidez/CrossValidate/Sewer/confusion_matrix/{class_label}_CV{icv}.png',dpi=fig.dpi)

# %% [markdown]
# # Extração de dados

# %%
years = [2019,2020,2021,2022]
stations = ['A047']
df_inmet = weather_series(stations,years)
df_inmet.head(3)
# Out:
#                      precipitacao  pressao_instantanea  pressao_max  \
# index
# 2019-01-01 00:00:00           0.8                899.2        899.2
# 2019-01-01 01:00:00           1.8                900.0        900.0
# 2019-01-01 02:00:00           0.0                900.3        900.4
#
#                      pressao_min  radiacao  temperatura_bulbo_seco  \
# index
# 2019-01-01 00:00:00        898.6       NaN                    19.3
# 2019-01-01 01:00:00        899.2       NaN                    19.1
# 2019-01-01 02:00:00        900.0       NaN                    18.9
#
#                      temperatura_orvalho_instantanea  temperatura_maxima  \
# index
# 2019-01-01 00:00:00                             18.1                19.4
# 2019-01-01 01:00:00                             18.2                19.3
# 2019-01-01 02:00:00                             18.4                19.2
#
#                      temperatura_minima  temperatura_maxima_orvalho  \
# index
# 2019-01-01 00:00:00                19.2                        18.4
# 2019-01-01 01:00:00                19.1                        18.3
# 2019-01-01 02:00:00                18.8                        18.5
#
#                      temperatura_minima_orvalho  umidade_relativa_maxima  \
# index
# 2019-01-01 00:00:00                        18.0                     94.0
# 2019-01-01 01:00:00                        18.0                     95.0
# 2019-01-01 02:00:00                        18.1                     97.0
#
#                      umidade_relativa_minima  umidade_relativa_instantanea  \
# index
# 2019-01-01 00:00:00                     92.0                          93.0
# 2019-01-01 01:00:00                     92.0                          94.0
# 2019-01-01 02:00:00                     94.0                          97.0
#
#                      vento_direcao  vento_rajada  vento_velocidade estacao  \
# index
# 2019-01-01 00:00:00          344.0           3.7               1.6    A047
# 2019-01-01 01:00:00          275.0           3.4               0.9    A047
# 2019-01-01 02:00:00          237.0           2.2               0.4    A047
#
#                      radiacao
# index
# 2019-01-01 00:00:00       NaN
# 2019-01-01 01:00:00       NaN
# 2019-01-01 02:00:00       NaN

# %%
df_inmet.head(3)
# Out:
#                      precipitacao  pressao_instantanea  pressao_max  \
# index
# 2019-01-01 00:00:00           0.8                899.2        899.2
# 2019-01-01 01:00:00           1.8                900.0        900.0
# 2019-01-01 02:00:00           0.0                900.3        900.4
#
#                      pressao_min  radiacao  temperatura_bulbo_seco  \
# index
# 2019-01-01 00:00:00        898.6       NaN                    19.3
# 2019-01-01 01:00:00        899.2       NaN                    19.1
# 2019-01-01 02:00:00        900.0       NaN                    18.9
#
#                      temperatura_orvalho_instantanea  temperatura_maxima  \
# index
# 2019-01-01 00:00:00                             18.1                19.4
# 2019-01-01 01:00:00                             18.2                19.3
# 2019-01-01 02:00:00                             18.4                19.2
#
#                      temperatura_minima  temperatura_maxima_orvalho  \
# index
# 2019-01-01 00:00:00                19.2                        18.4
# 2019-01-01 01:00:00                19.1                        18.3
# 2019-01-01 02:00:00                18.8                        18.5
#
#                      temperatura_minima_orvalho  umidade_relativa_maxima  \
# index
# 2019-01-01 00:00:00                        18.0                     94.0
# 2019-01-01 01:00:00                        18.0                     95.0
# 2019-01-01 02:00:00                        18.1                     97.0
#
#                      umidade_relativa_minima  umidade_relativa_instantanea  \
# index
# 2019-01-01 00:00:00                     92.0                          93.0
# 2019-01-01 01:00:00                     92.0                          94.0
# 2019-01-01 02:00:00                     94.0                          97.0
#
#                      vento_direcao  vento_rajada  vento_velocidade estacao  \
# index
# 2019-01-01 00:00:00          344.0           3.7               1.6    A047
# 2019-01-01 01:00:00          275.0           3.4               0.9    A047
# 2019-01-01 02:00:00          237.0           2.2               0.4    A047
#
#                      radiacao
# index
# 2019-01-01 00:00:00       NaN
# 2019-01-01 01:00:00       NaN
# 2019-01-01 02:00:00       NaN

# %%
# with open("//Srv-viacor01/pgo/PGOC/PGOCD/Paineis/13 - Machine Learning/Turbidez/TABELAS/Vazoes_esgoto_tratada.bin","rb") as f:
#     df = pickle.load(f)

# %%
df_vz = pd.read_csv('//srv-viacor01/pgo/PGOC/PGOCD/Paineis/13 - Machine Learning/Turbidez/eebgam.csv',index_col='index')
df_vz.head(3)
# Out:
#                      EEB.GAM.003.LIT.001.000.000
# index
# 2019-01-01 00:00:00                     1.871891
# 2019-01-01 00:10:00                     1.882175
# 2019-01-01 00:20:00                     1.888610

# %%
df_vz['AUX'] = pd.to_datetime(df_vz.reset_index()['index'].apply(lambda x: str(x)[:-5]+'00:00').values)
idx = df_vz.index
df = df_vz.set_index('AUX').join(df_inmet,lsuffix='AUX')
df.index = pd.to_datetime(idx)
df.head(3)
# Out:
#                      EEB.GAM.003.LIT.001.000.000  precipitacao  \
# index
# 2019-01-01 00:00:00                     1.871891           0.8
# 2019-01-01 00:10:00                     1.882175           0.8
# 2019-01-01 00:20:00                     1.888610           0.8
#
#                      pressao_instantanea  pressao_max  pressao_min  radiacao  \
# index
# 2019-01-01 00:00:00                899.2        899.2        898.6       NaN
# 2019-01-01 00:10:00                899.2        899.2        898.6       NaN
# 2019-01-01 00:20:00                899.2        899.2        898.6       NaN
#
#                      temperatura_bulbo_seco  temperatura_orvalho_instantanea  \
# index
# 2019-01-01 00:00:00                    19.3                             18.1
# 2019-01-01 00:10:00                    19.3                             18.1
# 2019-01-01 00:20:00                    19.3                             18.1
#
#                      temperatura_maxima  temperatura_minima  \
# index
# 2019-01-01 00:00:00                19.4                19.2
# 2019-01-01 00:10:00                19.4                19.2
# 2019-01-01 00:20:00                19.4                19.2
#
#                      temperatura_maxima_orvalho  temperatura_minima_orvalho  \
# index
# 2019-01-01 00:00:00                        18.4                        18.0
# 2019-01-01 00:10:00                        18.4                        18.0
# 2019-01-01 00:20:00                        18.4                        18.0
#
#                      umidade_relativa_maxima  umidade_relativa_minima  \
# index
# 2019-01-01 00:00:00                     94.0                     92.0
# 2019-01-01 00:10:00                     94.0                     92.0
# 2019-01-01 00:20:00                     94.0                     92.0
#
#                      umidade_relativa_instantanea  vento_direcao  \
# index
# 2019-01-01 00:00:00                          93.0          344.0
# 2019-01-01 00:10:00                          93.0          344.0
# 2019-01-01 00:20:00                          93.0          344.0
#
#                      vento_rajada  vento_velocidade estacao  radiacao
# index
# 2019-01-01 00:00:00           3.7               1.6    A047       NaN
# 2019-01-01 00:10:00           3.7               1.6    A047       NaN
# 2019-01-01 00:20:00           3.7               1.6    A047       NaN

# %% [markdown]
# # Entendimento dos dados

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 29360 entries, 2019-01-01 00:00:00 to 2021-03-09 21:50:00
# Data columns (total 20 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   EEB.GAM.003.LIT.001.000.000      29360 non-null  float64
#  1   precipitacao                     28502 non-null  float64
#  2   pressao_instantanea              28502 non-null  float64
#  3   pressao_max                      28484 non-null  float64
#  4   pressao_min                      28484 non-null  float64
#  5   radiacao                         5472 non-null   float64
#  6   temperatura_bulbo_seco           28508 non-null  float64
#  7   temperatura_orvalho_instantanea  27938 non-null  float64
#  8   temperatura_maxima               28490 non-null  float64
#  9   temperatura_minima               28490 non-null  float64
#  10  temperatura_maxima_orvalho       28340 non-null  float64
#  11  temperatura_minima_orvalho       28340 non-null  float64
#  12  umidade_relativa_maxima          28490 non-null  float64
#  13  umidade_relativa_minima          28490 non-null  float64
#  14  umidade_relativa_instantanea     27938 non-null  float64
#  15  vento_direcao                    28418 non-null  float64
#  16  vento_rajada                     28388 non-null  float64
#  17  vento_velocidade                 28418 non-null  float64
#  18  estacao                          29360 non-null  object
#  19  radiacao                         10722 non-null  float64
# dtypes: float64(19), object(1)
# memory usage: 4.7+ MB

# %%
nans_p = (df.isna().sum()/len(df))*100
pd.DataFrame(nans_p,columns=['Nulos (%)'])
# Out:
#                                  Nulos (%)
# EEB.GAM.003.LIT.001.000.000       0.000000
# precipitacao                      2.922343
# pressao_instantanea               2.922343
# pressao_max                       2.983651
# pressao_min                       2.983651
# radiacao                         81.362398
# temperatura_bulbo_seco            2.901907
# temperatura_orvalho_instantanea   4.843324
# temperatura_maxima                2.963215
# temperatura_minima                2.963215
# temperatura_maxima_orvalho        3.474114
# temperatura_minima_orvalho        3.474114
# umidade_relativa_maxima           2.963215
# umidade_relativa_minima           2.963215
# umidade_relativa_instantanea      4.843324
# vento_direcao                     3.208447
# vento_rajada                      3.310627
# vento_velocidade                  3.208447
# estacao                           0.000000
# radiacao                         63.480926

# %%
df.describe().T
# Out:
#                                    count         mean          std    min  \
# EEB.GAM.003.LIT.001.000.000      29360.0     1.662295     0.582537    0.0
# precipitacao                     28502.0     0.468304     2.839530    0.0
# pressao_instantanea              28502.0   898.348979     1.851491  891.4
# pressao_max                      28484.0   898.616402     1.822473  891.6
# pressao_min                      28484.0   898.080670     1.857959  891.2
# radiacao                          5472.0  1699.396382  1292.704506    0.0
# temperatura_bulbo_seco           28508.0    22.369749     3.466635   16.2
# temperatura_orvalho_instantanea  27938.0    18.398468     1.594926   11.6
# temperatura_maxima               28490.0    23.082984     3.714695   16.7
# temperatura_minima               28490.0    21.696602     3.186485   16.1
# temperatura_maxima_orvalho       28340.0    18.991955     1.566752   12.6
# temperatura_minima_orvalho       28340.0    17.821334     1.666277   10.9
# umidade_relativa_maxima          28490.0    84.042120    15.352200   35.0
# umidade_relativa_minima          28490.0    76.647806    17.946727   29.0
# umidade_relativa_instantanea     27938.0    81.026988    16.450670   32.0
# vento_direcao                    28418.0   168.186009   115.607756    1.0
# vento_rajada                     28388.0     4.756200     2.267484    0.7
# vento_velocidade                 28418.0     1.936822     1.137205    0.1
# radiacao                         10722.0  1496.254225  1222.379362    0.0
#
#                                         25%          50%          75%  \
# EEB.GAM.003.LIT.001.000.000        1.618106     1.766417     1.892781
# precipitacao                       0.000000     0.000000     0.000000
# pressao_instantanea              897.100000   898.400000   899.700000
# pressao_max                      897.400000   898.700000   899.900000
# pressao_min                      896.900000   898.200000   899.400000
# radiacao                         417.900000  1594.450000  2860.525000
# temperatura_bulbo_seco            19.600000    21.300000    24.900000
# temperatura_orvalho_instantanea   17.600000    18.700000    19.500000
# temperatura_maxima                20.000000    22.000000    25.900000
# temperatura_minima                19.300000    20.600000    23.700000
# temperatura_maxima_orvalho        18.100000    19.200000    20.000000
# temperatura_minima_orvalho        16.900000    18.200000    19.000000
# umidade_relativa_maxima           75.000000    89.000000    97.000000
# umidade_relativa_minima           63.000000    80.000000    93.000000
# umidade_relativa_instantanea      70.000000    85.000000    95.000000
# vento_direcao                     61.000000   143.000000   275.000000
# vento_rajada                       3.000000     4.400000     6.200000
# vento_velocidade                   1.100000     1.700000     2.600000
# radiacao                         333.600000  1254.700000  2563.900000
#
#                                          max
# EEB.GAM.003.LIT.001.000.000         3.090987
# precipitacao                       60.200000
# pressao_instantanea               903.400000
# pressao_max                       903.600000
# pressao_min                       903.400000
# radiacao                         4142.500000
# temperatura_bulbo_seco             32.200000
# temperatura_orvalho_instantanea    23.200000
# temperatura_maxima                 32.500000
# temperatura_minima                 31.600000
# temperatura_maxima_orvalho         23.200000
# temperatura_minima_orvalho         21.200000
# umidade_relativa_maxima           100.000000
# umidade_relativa_minima           100.000000
# umidade_relativa_instantanea      100.000000
# vento_direcao                     360.000000
# vento_rajada                       16.000000
# vento_velocidade                    7.700000
# radiacao                         4283.200000

# %% [markdown]
# # Preparação

# %%
df['estravazamento'] = df['EEB.GAM.003.LIT.001.000.000'].apply(lambda x: 1 if x > 2.7 else 0)

# %%
df.estravazamento.value_counts()
# Out:
# 0    28610
# 1      750
# Name: estravazamento, dtype: int64

# %%
df.drop(['radiacao'],axis=1,inplace=True)
df.drop(['estacao'],axis=1,inplace=True)
df.drop(['EEB.GAM.003.LIT.001.000.000'],axis=1,inplace=True)
df.reset_index(drop=True,inplace=True)

# %%
df.dropna(inplace=True)

# %%
df.estravazamento.value_counts()
# Out:
# 0    27019
# 1      655
# Name: estravazamento, dtype: int64

# %% [markdown]
# # Separação

# %%
from sklearn.ensemble import GradientBoostingClassifier,RandomForestClassifier
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier

# %%
from sklearn.feature_selection import mutual_info_classif
from sklearn.feature_selection import SelectKBest
from sklearn.pipeline import Pipeline 
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import recall_score, f1_score, precision_score,confusion_matrix, classification_report

# %%
df
# Out:
#        precipitacao  pressao_instantanea  pressao_max  pressao_min  \
# 0               0.8                899.2        899.2        898.6
# 1               0.8                899.2        899.2        898.6
# 2               0.8                899.2        899.2        898.6
# 3               0.8                899.2        899.2        898.6
# 4               0.8                899.2        899.2        898.6
# ...             ...                  ...          ...          ...
# 29355          32.8                895.2        895.2        894.3
# 29356          32.8                895.2        895.2        894.3
# 29357          32.8                895.2        895.2        894.3
# 29358          32.8                895.2        895.2        894.3
# 29359          32.8                895.2        895.2        894.3
#
#        temperatura_bulbo_seco  temperatura_orvalho_instantanea  \
# 0                        19.3                             18.1
# 1                        19.3                             18.1
# 2                        19.3                             18.1
# 3                        19.3                             18.1
# 4                        19.3                             18.1
# ...                       ...                              ...
# 29355                    19.5                             19.5
# 29356                    19.5                             19.5
# 29357                    19.5                             19.5
# 29358                    19.5                             19.5
# 29359                    19.5                             19.5
#
#        temperatura_maxima  temperatura_minima  temperatura_maxima_orvalho  \
# 0                    19.4                19.2                        18.4
# 1                    19.4                19.2                        18.4
# 2                    19.4                19.2                        18.4
# 3                    19.4                19.2                        18.4
# 4                    19.4                19.2                        18.4
# ...                   ...                 ...                         ...
# 29355                22.5                18.6                        19.6
# 29356                22.5                18.6                        19.6
# 29357                22.5                18.6                        19.6
# 29358                22.5                18.6                        19.6
# 29359                22.5                18.6                        19.6
#
#        temperatura_minima_orvalho  umidade_relativa_maxima  \
# 0                            18.0                     94.0
# 1                            18.0                     94.0
# 2                            18.0                     94.0
# 3                            18.0                     94.0
# 4                            18.0                     94.0
# ...                           ...                      ...
# 29355                        17.1                    100.0
# 29356                        17.1                    100.0
# 29357                        17.1                    100.0
# 29358                        17.1                    100.0
# 29359                        17.1                    100.0
#
#        umidade_relativa_minima  umidade_relativa_instantanea  vento_direcao  \
# 0                         92.0                          93.0          344.0
# 1                         92.0                          93.0          344.0
# 2                         92.0                          93.0          344.0
# 3                         92.0                          93.0          344.0
# 4                         92.0                          93.0          344.0
# ...                        ...                           ...            ...
# 29355                     72.0                         100.0          115.0
# 29356                     72.0                         100.0          115.0
# 29357                     72.0                         100.0          115.0
# 29358                     72.0                         100.0          115.0
# 29359                     72.0                         100.0          115.0
#
#        vento_rajada  vento_velocidade  estravazamento
# 0               3.7               1.6               0
# 1               3.7               1.6               0
# 2               3.7               1.6               0
# 3               3.7               1.6               0
# 4               3.7               1.6               0
# ...             ...               ...             ...
# 29355          10.9               4.8               0
# 29356          10.9               4.8               0
# 29357          10.9               4.8               0
# 29358          10.9               4.8               0
# 29359          10.9               4.8               0
#
# [27674 rows x 17 columns]

# %%
dt = df.copy()
y_dt = dt.pop('estravazamento')
x_dt = dt

# %%
# BALANCED
scale_pos_weight = np.sqrt(df.estravazamento.value_counts()[0]/df.estravazamento.value_counts()[1])

# %%
# MODELS
skb = SelectKBest(mutual_info_classif, k=5)
ctb_sqrt = CatBoostClassifier(verbose=0,auto_class_weights = 'SqrtBalanced',loss_function='Logloss')
ctb_blcd = CatBoostClassifier(verbose=0,auto_class_weights = 'Balanced',loss_function='Logloss')
xgb = XGBClassifier(objective='binary:logistic',scale_pos_weight=scale_pos_weight)
gbc = GradientBoostingClassifier()

# %%
# PIPELINES
ml_models = {'XGBClassifier':Pipeline([('SKB',skb),
                                        ('XGB',xgb)]),
             
             'CatBoostClassifier_SQRT':Pipeline([('SKB',skb),
                                             ('CTB',ctb_sqrt)]),

             'CatBoostClassifier_BLCD':Pipeline([('SKB',skb),
                                             ('CTB',ctb_blcd)]),

             'GradientBoostingClassifier':Pipeline([('SKB',skb),
                                                     ('GBC',gbc)])
            }

# %%
def make_df_confusion_matrix(cm,model_name):
    col = [(model_name,'medidor','1'),(model_name,'medidor','0')]
    idx = ['1','0']
    df = pd.DataFrame(cm,columns=col,index=idx)
    df.columns = pd.MultiIndex.from_tuples(df.columns)

    return df

# %%
# CROSS VALIDATION - BEST MODEL
skf = StratifiedKFold(n_splits=3, random_state=43,shuffle=True)


results_cv = pd.DataFrame()
confusion_matrix_cv = pd.DataFrame()
for model_name in tqdm(ml_models.keys()):
  sleep(0.001)
  confusion_mtx_model = pd.DataFrame()
  for cv,(train_index, test_index) in enumerate(skf.split(x_dt,y_dt),1):
      # ============================ split data ===================================
      X_train, y_train = x_dt.iloc[train_index],y_dt.iloc[train_index]
      X_test, y_test = x_dt.iloc[test_index],y_dt.iloc[test_index]

      # ============================ train model ===================================
      ml_models[model_name].fit(X_train, y_train)

      # ============================ predict model ===================================
      y_hat = ml_models[model_name].predict(X_test)

      # ============================ confusion matrix ===================================
      cm = confusion_matrix(y_test, y_hat)
      df_cm = make_df_confusion_matrix(cm,model_name)
      confusion_mtx_model = confusion_mtx_model.append(df_cm)    
      
      
      # ============================ classifier reports ===================================
      c_report = classification_report(y_test, y_hat,output_dict=True)
      c_report['model'] = model_name
      c_report['CV'] = cv

      results_cv = results_cv.append(pd.DataFrame(c_report))
  confusion_matrix_cv = pd.concat([confusion_matrix_cv,confusion_mtx_model],axis=1)
# SAVE RESULTS  
confusion_matrix_cv.to_csv(f'//srv-viacor01/pgo/PGOC/PGOCD/Paineis/13 - Machine Learning/Turbidez/CrossValidate/Swear/confusion_matrix/confusion_matrix_sewer.txt', header=True, index=True, sep=',', mode='w')
results_cv.to_csv(f'//srv-viacor01/pgo/PGOC/PGOCD/Paineis/13 - Machine Learning/Turbidez/CrossValidate/Swear/reports/cross_validation_sewer.txt', header=True, index=True, sep=',', mode='w')
# Out:
#  75%|███████▌  | 3/4 [02:42<00:59, 59.61s/it]

# %%
# Results
results = pd.read_csv('//srv-viacor01/pgo/PGOC/PGOCD/Paineis/13 - Machine Learning/Turbidez/CrossValidate/Swear/reports/cross_validation_sewer.txt',index_col=[0])
results = results_cv.copy()
for i in results.index.unique()[0:3]:
  display(results[results.index==i])
# Out:
#                   0         1  accuracy  macro avg  weighted avg  \
# precision  0.998771  0.758242  0.991653   0.878506      0.993087
# precision  0.998773  0.803089  0.993279   0.900931      0.994128
# precision  0.998104  0.785156  0.992194   0.891630      0.993072
# precision  0.998326  0.768939  0.991762   0.883633      0.992905
# precision  0.998217  0.815261  0.993279   0.906739      0.993874
# precision  0.998104  0.785156  0.992194   0.891630      0.993072
# precision  0.998771  0.752727  0.991436   0.875749      0.992957
# precision  0.998770  0.729825  0.990461   0.864297      0.992385
# precision  0.998102  0.758491  0.991219   0.878297      0.992439
# precision  0.980510  0.951220  0.980379   0.965865      0.979817
# precision  0.980937  0.977778  0.980921   0.979357      0.980862
# precision  0.980824  0.913043  0.980486   0.946934      0.979222
#
#                                 model  CV
# precision               XGBClassifier   1
# precision               XGBClassifier   2
# precision               XGBClassifier   3
# precision     CatBoostClassifier_SQRT   1
# precision     CatBoostClassifier_SQRT   2
# precision     CatBoostClassifier_SQRT   3
# precision     CatBoostClassifier_BLCD   1
# precision     CatBoostClassifier_BLCD   2
# precision     CatBoostClassifier_BLCD   3
# precision  GradientBoostingClassifier   1
# precision  GradientBoostingClassifier   2
# precision  GradientBoostingClassifier   3
#                0         1  accuracy  macro avg  weighted avg  \
# recall  0.992672  0.949541  0.991653   0.971107      0.991653
# recall  0.994337  0.949772  0.993279   0.972054      0.993279
# recall  0.993893  0.922018  0.992194   0.957956      0.992194
# recall  0.993227  0.931193  0.991762   0.962210      0.991762
# recall  0.994892  0.926941  0.993279   0.960916      0.993279
# recall  0.993893  0.922018  0.992194   0.957956      0.992194
# recall  0.992450  0.949541  0.991436   0.970996      0.991436
# recall  0.991450  0.949772  0.990461   0.970611      0.990461
# recall  0.992894  0.922018  0.991219   0.957456      0.991219
# recall  0.999778  0.178899  0.980379   0.589339      0.980379
# recall  0.999889  0.200913  0.980921   0.600401      0.980921
# recall  0.999556  0.192661  0.980486   0.596108      0.980486
#
#                              model  CV
# recall               XGBClassifier   1
# recall               XGBClassifier   2
# recall               XGBClassifier   3
# recall     CatBoostClassifier_SQRT   1
# recall     CatBoostClassifier_SQRT   2
# recall     CatBoostClassifier_SQRT   3
# recall     CatBoostClassifier_BLCD   1
# recall     CatBoostClassifier_BLCD   2
# recall     CatBoostClassifier_BLCD   3
# recall  GradientBoostingClassifier   1
# recall  GradientBoostingClassifier   2
# recall  GradientBoostingClassifier   3
#                  0         1  accuracy  macro avg  weighted avg  \
# f1-score  0.995712  0.843177  0.991653   0.919445      0.992108
# f1-score  0.996550  0.870293  0.993279   0.933422      0.993553
# f1-score  0.995994  0.848101  0.992194   0.922048      0.992499
# f1-score  0.995770  0.842324  0.991762   0.919047      0.992144
# f1-score  0.996552  0.867521  0.993279   0.932037      0.993489
# f1-score  0.995994  0.848101  0.992194   0.922048      0.992499
# f1-score  0.995601  0.839757  0.991436   0.917679      0.991918
# f1-score  0.995096  0.825397  0.990461   0.910247      0.991068
# f1-score  0.995491  0.832298  0.991219   0.913895      0.991634
# f1-score  0.990050  0.301158  0.980379   0.645604      0.973771
# f1-score  0.990322  0.333333  0.980921   0.661828      0.974725
# f1-score  0.990101  0.318182  0.980486   0.654142      0.974221
#
#                                model  CV
# f1-score               XGBClassifier   1
# f1-score               XGBClassifier   2
# f1-score               XGBClassifier   3
# f1-score     CatBoostClassifier_SQRT   1
# f1-score     CatBoostClassifier_SQRT   2
# f1-score     CatBoostClassifier_SQRT   3
# f1-score     CatBoostClassifier_BLCD   1
# f1-score     CatBoostClassifier_BLCD   2
# f1-score     CatBoostClassifier_BLCD   3
# f1-score  GradientBoostingClassifier   1
# f1-score  GradientBoostingClassifier   2
# f1-score  GradientBoostingClassifier   3

# %%
# Mean results
results = pd.read_csv('//srv-viacor01/pgo/PGOC/PGOCD/Paineis/13 - Machine Learning/Turbidez/CrossValidate/Swear/reports/cross_validation_sewer.txt',index_col=[0]).reset_index()
results.drop(['CV'],axis=1,inplace=True)
results = results[results['index']!='support']
results = results.groupby(['model','index'])[results.columns].mean()
display(
results.style.background_gradient(cmap='coolwarm'),
results[results.index=='f1-score'].style.background_gradient(cmap='coolwarm'),
)
# Out:
# <style type="text/css">
# #T_eb22f_row0_col0 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_eb22f_row0_col1 {
#   background-color: #e36c55;
#   color: #f1f1f1;
# }
# #T_eb22f_row0_col2, #T_eb22f_row1_col2, #T_eb22f_row2_col2, #T_eb22f_row3_col3 {
#   background-color: #da5a49;
#   color: #f1f1f1;
# }
# #T_eb22f_row0_col3 {
#   background-color: #e26952;
#   color: #f1f1f1;
# }
# #T_eb22f_row0_col4 {
#   background-color: #d65244;
#   color: #f1f1f1;
# }
# #T_eb22f_row1_col0, #T_eb22f_row10_col0 {
#   background-color: #cb3e38;
#   color: #f1f1f1;
# }
# #T_eb22f_row1_col1 {
#   background-color: #f59f80;
#   color: #000000;
# }
# #T_eb22f_row1_col3 {
#   background-color: #f49a7b;
#   color: #000000;
# }
# #T_eb22f_row1_col4 {
#   background-color: #c43032;
#   color: #f1f1f1;
# }
# #T_eb22f_row2_col0 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_eb22f_row2_col1, #T_eb22f_row7_col3, #T_eb22f_row11_col1 {
#   background-color: #b70d28;
#   color: #f1f1f1;
# }
# #T_eb22f_row2_col3, #T_eb22f_row3_col2, #T_eb22f_row4_col2, #T_eb22f_row5_col2, #T_eb22f_row7_col1, #T_eb22f_row8_col0, #T_eb22f_row9_col2, #T_eb22f_row10_col2, #T_eb22f_row10_col4, #T_eb22f_row11_col2, #T_eb22f_row11_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_eb22f_row2_col4, #T_eb22f_row9_col1 {
#   background-color: #dd5f4b;
#   color: #f1f1f1;
# }
# #T_eb22f_row3_col0, #T_eb22f_row9_col0 {
#   background-color: #ec8165;
#   color: #f1f1f1;
# }
# #T_eb22f_row3_col1 {
#   background-color: #de614d;
#   color: #f1f1f1;
# }
# #T_eb22f_row3_col4, #T_eb22f_row9_col4 {
#   background-color: #c12b30;
#   color: #f1f1f1;
# }
# #T_eb22f_row4_col0 {
#   background-color: #d0473d;
#   color: #f1f1f1;
# }
# #T_eb22f_row4_col1 {
#   background-color: #ef886b;
#   color: #f1f1f1;
# }
# #T_eb22f_row4_col3 {
#   background-color: #ed8366;
#   color: #f1f1f1;
# }
# #T_eb22f_row4_col4 {
#   background-color: #b50927;
#   color: #f1f1f1;
# }
# #T_eb22f_row5_col0 {
#   background-color: #f7ad90;
#   color: #000000;
# }
# #T_eb22f_row5_col1 {
#   background-color: #bd1f2d;
#   color: #f1f1f1;
# }
# #T_eb22f_row5_col3 {
#   background-color: #ba162b;
#   color: #f1f1f1;
# }
# #T_eb22f_row5_col4 {
#   background-color: #c73635;
#   color: #f1f1f1;
# }
# #T_eb22f_row6_col0 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_eb22f_row6_col1 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_eb22f_row6_col2, #T_eb22f_row6_col4, #T_eb22f_row7_col0, #T_eb22f_row7_col2, #T_eb22f_row8_col1, #T_eb22f_row8_col2, #T_eb22f_row8_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_eb22f_row6_col3 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_eb22f_row7_col4 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_eb22f_row8_col4 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_eb22f_row9_col3 {
#   background-color: #d95847;
#   color: #f1f1f1;
# }
# #T_eb22f_row10_col1 {
#   background-color: #f08b6e;
#   color: #f1f1f1;
# }
# #T_eb22f_row10_col3 {
#   background-color: #ee8669;
#   color: #f1f1f1;
# }
# #T_eb22f_row11_col0 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_eb22f_row11_col4 {
#   background-color: #c83836;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_eb22f">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eb22f_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_eb22f_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_eb22f_level0_col2" class="col_heading level0 col2" >accuracy</th>
#       <th id="T_eb22f_level0_col3" class="col_heading level0 col3" >macro avg</th>
#       <th id="T_eb22f_level0_col4" class="col_heading level0 col4" >weighted avg</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="index_name level1" >index</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eb22f_level0_row0" class="row_heading level0 row0" rowspan="3">CatBoostClassifier_BLCD</th>
#       <th id="T_eb22f_level1_row0" class="row_heading level1 row0" >f1-score</th>
#       <td id="T_eb22f_row0_col0" class="data row0 col0" >0.995396</td>
#       <td id="T_eb22f_row0_col1" class="data row0 col1" >0.832484</td>
#       <td id="T_eb22f_row0_col2" class="data row0 col2" >0.991039</td>
#       <td id="T_eb22f_row0_col3" class="data row0 col3" >0.913940</td>
#       <td id="T_eb22f_row0_col4" class="data row0 col4" >0.991540</td>
#     </tr>
#     <tr>
#       <th id="T_eb22f_level1_row1" class="row_heading level1 row1" >precision</th>
#       <td id="T_eb22f_row1_col0" class="data row1 col0" >0.998548</td>
#       <td id="T_eb22f_row1_col1" class="data row1 col1" >0.747014</td>
#       <td id="T_eb22f_row1_col2" class="data row1 col2" >0.991039</td>
#       <td id="T_eb22f_row1_col3" class="data row1 col3" >0.872781</td>
#       <td id="T_eb22f_row1_col4" class="data row1 col4" >0.992594</td>
#     </tr>
#     <tr>
#       <th id="T_eb22f_level1_row2" class="row_heading level1 row2" >recall</th>
#       <td id="T_eb22f_row2_col0" class="data row2 col0" >0.992265</td>
#       <td id="T_eb22f_row2_col1" class="data row2 col1" >0.940444</td>
#       <td id="T_eb22f_row2_col2" class="data row2 col2" >0.991039</td>
#       <td id="T_eb22f_row2_col3" class="data row2 col3" >0.966354</td>
#       <td id="T_eb22f_row2_col4" class="data row2 col4" >0.991039</td>
#     </tr>
#     <tr>
#       <th id="T_eb22f_level0_row3" class="row_heading level0 row3" rowspan="3">CatBoostClassifier_SQRT</th>
#       <th id="T_eb22f_level1_row3" class="row_heading level1 row3" >f1-score</th>
#       <td id="T_eb22f_row3_col0" class="data row3 col0" >0.996106</td>
#       <td id="T_eb22f_row3_col1" class="data row3 col1" >0.852649</td>
#       <td id="T_eb22f_row3_col2" class="data row3 col2" >0.992412</td>
#       <td id="T_eb22f_row3_col3" class="data row3 col3" >0.924377</td>
#       <td id="T_eb22f_row3_col4" class="data row3 col4" >0.992711</td>
#     </tr>
#     <tr>
#       <th id="T_eb22f_level1_row4" class="row_heading level1 row4" >precision</th>
#       <td id="T_eb22f_row4_col0" class="data row4 col0" >0.998216</td>
#       <td id="T_eb22f_row4_col1" class="data row4 col1" >0.789786</td>
#       <td id="T_eb22f_row4_col2" class="data row4 col2" >0.992412</td>
#       <td id="T_eb22f_row4_col3" class="data row4 col3" >0.894001</td>
#       <td id="T_eb22f_row4_col4" class="data row4 col4" >0.993284</td>
#     </tr>
#     <tr>
#       <th id="T_eb22f_level1_row5" class="row_heading level1 row5" >recall</th>
#       <td id="T_eb22f_row5_col0" class="data row5 col0" >0.994004</td>
#       <td id="T_eb22f_row5_col1" class="data row5 col1" >0.926717</td>
#       <td id="T_eb22f_row5_col2" class="data row5 col2" >0.992412</td>
#       <td id="T_eb22f_row5_col3" class="data row5 col3" >0.960361</td>
#       <td id="T_eb22f_row5_col4" class="data row5 col4" >0.992412</td>
#     </tr>
#     <tr>
#       <th id="T_eb22f_level0_row6" class="row_heading level0 row6" rowspan="3">GradientBoostingClassifier</th>
#       <th id="T_eb22f_level1_row6" class="row_heading level1 row6" >f1-score</th>
#       <td id="T_eb22f_row6_col0" class="data row6 col0" >0.990158</td>
#       <td id="T_eb22f_row6_col1" class="data row6 col1" >0.317558</td>
#       <td id="T_eb22f_row6_col2" class="data row6 col2" >0.980596</td>
#       <td id="T_eb22f_row6_col3" class="data row6 col3" >0.653858</td>
#       <td id="T_eb22f_row6_col4" class="data row6 col4" >0.974239</td>
#     </tr>
#     <tr>
#       <th id="T_eb22f_level1_row7" class="row_heading level1 row7" >precision</th>
#       <td id="T_eb22f_row7_col0" class="data row7 col0" >0.980757</td>
#       <td id="T_eb22f_row7_col1" class="data row7 col1" >0.947347</td>
#       <td id="T_eb22f_row7_col2" class="data row7 col2" >0.980596</td>
#       <td id="T_eb22f_row7_col3" class="data row7 col3" >0.964052</td>
#       <td id="T_eb22f_row7_col4" class="data row7 col4" >0.979967</td>
#     </tr>
#     <tr>
#       <th id="T_eb22f_level1_row8" class="row_heading level1 row8" >recall</th>
#       <td id="T_eb22f_row8_col0" class="data row8 col0" >0.999741<

# %%
cmatrix = pd.read_csv('//srv-viacor01/pgo/PGOC/PGOCD/Paineis/13 - Machine Learning/Turbidez/CrossValidate/Swear/confusion_matrix/confusion_matrix_sewer.txt',header=[0,1,2],index_col=[0])
cmatrix
# Out:
#   XGBClassifier      CatBoostClassifier_SQRT      CatBoostClassifier_BLCD  \
#         medidor                      medidor                      medidor
#               1    0                       1    0                       1
# 1          8941   66                    8946   61                    8939
# 0            11  207                      15  203                      11
# 1          8955   51                    8960   46                    8929
# 0            11  208                      16  203                      11
# 1          8951   55                    8951   55                    8942
# 0            17  201                      17  201                      17
#
#        GradientBoostingClassifier
#                           medidor
#      0                          1   0
# 1   68                       9005   2
# 0  207                        179  39
# 1   77                       9005   1
# 0  208                        175  44
# 1   64                       9002   4
# 0  201                        176  42

# %%
cmatrix.style.background_gradient(cmap='coolwarm',axis=0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\lucaguarda\Anaconda3\lib\site-packages\IPython\core\formatters.py:343, in BaseFormatter.__call__(self, obj)
#     <a href='file:///c%3A/Users/lucaguarda/Anaconda3/lib/site-packages/IPython/core/formatters.py?line=340'>341</a>     method = get_real_method(obj, self.print_method)
#     <a href='file:///c%3A/Users/lucaguarda/Anaconda3/lib/site-packages/IPython/core/formatters.py?line=341'>342</a>     if method is not None:
# --> <a href='file:///c%3A/Users/lucaguarda/Anaconda3/lib/site-packages/IPython/core/formatters.py?line=342'>343</a>         return method()
#     <a href='file:///c%3A/Users/lucaguarda/Anaconda3/lib/site-packages/IPython/core/formatters.py?line=343'>344</a>     return None
#     <a href='file:///c%3A/Users/lucaguarda/Anaconda3/lib/site-packages/IPython/core/formatters.py?line=344'>345</a> else:
#
# File c:\Users\lucaguarda\Anaconda3\lib\site-packages\pandas\io\formats\style.py:272, in Styler._repr_html_(self)
#     <a href='file:///c%3A/Users/lucaguarda/Anaconda3/lib/site-packages/pandas/io/formats/style.py?line=266'>267</a> """
#     <a href='file:///c%3A/Users/lucaguarda/Anaconda3/lib/site-packages/pandas/io/formats/style.py?line=267'>268</a> Hooks into Jupyter notebook rich display system, which calls _repr_html_ by
#     <a href='file:///c%3A/Users/lucaguarda/Anaconda3/lib/site-packages/pandas/io/formats/style.py?line=268'>269</a> default if an object is returned at the end of a cell.
#     <a href='file:///c%3A/Users/lucaguarda/Anaconda3/lib/site-packages/pandas/io/formats/style.py?line=269'>270</a> """
#     <a href='file:///c%3A/Users/lucaguarda/Anaconda3/lib/site-packages/pandas/io/formats/style.py?line=270'>271</a> if get_option("styler.render.repr") == "html":
# --> <a href='file:///c%3A/Users/lucaguarda/Anaconda3/lib/site-packages/pandas/io/formats/style.py?line=271'>272</a>     return self.to_html()
#     <a href='file:///c%3A/Users/lucaguarda/Anaconda3/lib/site-packages/pandas/io/formats/style.py?line=272'>273</a> return None
#
# File c:\Users\lucaguarda\Anaconda3\lib\site-packages\pandas\io\formats\style.py:1178, in Styler.to_html(self, buf, table_uuid, table_attributes, sparse_index, sparse_columns, bold_headers, caption, max_rows, max_columns, encoding, doctype_html, exclude_styles, **kwargs)
#    <a href='file:///c%3A/Users/lucaguarda/Anaconda3/lib/site-packages/pandas/io/formats/style.py?line=1175'>1176</a> encoding = encoding or get_option("styler.render.encoding")
#    <a href='file:///c%3A/Users/lucaguarda/Anaconda3/lib/site-packages/pandas/io/formats/style.py?line=1176'>1177</a> # Build HTML string..
# -> <a href='file:///c%3A/Users/lucaguarda/Anaconda3/lib/site-packages/pandas/io/formats/style.py?line=1177'>1178</a> html = obj._render_html(
#    <a href='file:///c%3A/Users/lucaguarda/Anaconda3/lib/site-packages/pandas/io/formats/style.py?line=1178'>1179</a>     sparse_index=sparse_index,
#    <a href='file:///c%3A/Users/lucaguarda/Anaconda3/lib/site-packages/pandas/io/formats/style.py?line=1179'>1180</a>     sparse_columns=sparse_columns,
#    <a href='file:///c%3A/Users/lucaguarda/Anaconda3/lib/site-packages/pandas/io/formats/style.py?line=1180'>1181</a>     max_rows=max_rows,
#    <a href='file:///c%3A/Users/lucaguarda/Anaconda3/lib/site-packages/pandas/io/formats/style.py?line=1181'>1182</a>     max_cols=max_columns,
#    <a href='file:///c%3A/Users/lucaguarda/Anaconda3/lib/site-packages/pandas/io/formats/style.py?line=1182'>1183</a>     exclude_styles=exclude_styles,
#    <a href='file:///c%3A/Users/lucaguarda/Anaconda3/lib/site-packages/pandas/io/formats/style.py?line=1183'>1184</a>     encoding=encoding,
#    <a href='file:///c%3A/Users/lucaguarda/Anaconda3/lib/site-packages/pandas/io/formats/style.py?line=1184'>1185</a>     doctype_html=doctype_html,
#    <a href='file:///c%3A/Users/lucaguarda/Anaconda3/lib/site-packages/pandas/io/formats/style.py?line=1185'>1186</a>     **kwargs,
#    <a href='file:///c%3A/Users/lucaguarda/Anaconda3/lib/site-packages/pandas/io/formats/style.py?line=1186'>1187</a> )
#    <a href='file:///c%3A/Users/lucaguarda/Anaconda3/lib/site-packages/pandas/io/formats/style.py?line=1188'>1189</a> return save_to_buffer(
#    <a href='file:///c%3A/Users/lucaguarda/Anaconda3/lib/site-packages/pandas/io/formats/style.py?line=1189'>1190</a>     html, buf=buf, encoding=(encoding if buf is not None else None)
#    <a href='file:///c%3A/Users/lucaguarda/Anaconda3/lib/site-packages/pandas/io/formats/style.py?line=1190'>1191</a> )
#
# File c:\Users\lucaguarda\Anaconda3\lib\site-packages\pandas\io\formats\style_render.py:162, in StylerRenderer._render_html(self, sparse_index, sparse_columns, max_rows, max_cols, **kwargs)
#     <a href='file:///c%3A/Users/lucaguarda/Anaconda3/lib/site-packages/pandas/io/formats/style_render.py?line=149'>150</a> def _render_html(
#     <a href='file:///c%3A/Users/lucaguarda/Anaconda3/lib/site-packages/pandas/io/formats/style_render.py?line=150'>151</a>     self,
#     <a href='file:///c%3A/Users/lucaguarda/Anaconda3/lib/site-packages/pandas/io/formats/style_render.py?line=151'>152</a>     sparse_index: bool,
#    (...)
#     <a href='file:///c%3A/Users/lucaguarda/Anaconda3/lib/site-packages/pandas/io/formats/style_render.py?line=155'>156</a>     **kwargs,
#     <a href='file:///c%3A/Users/lucaguarda/Anaconda3/lib/site-packages/pandas/io/formats/style_render.py?line=156'>157</a> ) -> str:
#     <a href='file:///c%3A/Users/lucaguarda/Anaconda3/lib/site-packages/pandas/io/formats/style_render.py?line=157'>158</a>     """
#     <a href='file:///c%3A/Users/lucaguarda/Anaconda3/lib/site-packages/pandas/io/formats/style_render.py?line=158'>159</a>     Renders the ``Styler`` including all applied styles to HTML.
#     <a href='file:///c%3A/Users/lucaguarda/Anaconda3/lib/site-packages/pandas/io/formats/style_render.py?line=159'>160</a>     Generates a dict with necessary kwargs passed to jinja2 template.
#     <a href='file:///c%3A/Users/lucaguarda/Anaconda3/lib/site-packages/pandas/io/formats/style_render.py?line=160'>161</a>     """
# --> <a href='file:///c%3A/Users/lucaguarda/Anaconda3/lib/site-packages/pandas/io/formats/style_render.py?line=161'>162</a>     self._compute()
#     <a href='file:///c%3A/Users/lucaguarda/Anaconda3/lib/site-packages/pandas/io/formats/style_render.py?line=162'>163</a>     # TODO: namespace all the pandas keys
#     <a href='file:///c%3A/Users/lucaguarda/Anaconda3/lib/site-packages/pandas/io/formats/style_render.py?line=163'>164</a>     d = self._translate(sparse_index, sparse_columns, max_rows, max_cols)
#
# File c:\Users\lucaguarda\Anaconda3\lib\site-packages\pandas\io\formats\style_render.py:205, in StylerRenderer._compute(self)
#     <a href='file:///c%3A/Users/lucaguarda/Anaconda3/lib/site-packages/pandas/io/formats/style_render.py?line=202'>203</a> r = self
#     <a href='file:///c%3A/Users/lucaguarda/Anaconda3/lib/site-packages/pandas/io/formats/style_render.py?line=203'>204</a> for func, args, kwargs in self._todo:
# --> <a href='file:///c%3A/Users/lucaguarda/Anaconda3/lib/site-packages/pandas/io/formats/style_render.py?line=204'>205</a>     r = func(self)(*args, **kwargs)
#     <a href='file:///c%3A/Users/lucaguarda/Anaconda3/lib/site-packages/pandas/io/formats/style_render.py?line=205'>206</a> return r
#
# File c:\Users\lucaguarda\Anaconda3\lib\site-packages\pandas\io\formats\style.py:1467, in Styler._apply(self, func, axis, subset, **kwargs)
#    <a href='file:///c%3A/Users/lucaguarda/Anaconda3/lib/site-packages/pandas/io/formats/style.py?line=1462'>1463</a> if not all(result.columns.isin(data.columns)):
#    <a href='file:///c%3A/Users/lucaguarda/Anaconda3/lib/site-packages/pandas/io/formats/style.py?line=1463'>1464</a>     raise ValueError(
#    <a href='file:///c%3A/Users/lucaguarda/Anaconda3/lib/site-packages/pandas/io/formats/style.py?line=1464'>1465</a>         msg.format("columns", result.columns.shape, data.columns.shape)
#    <a href='file:///c%3A/Users/lucaguarda/Anaconda3/lib/site-packages/pandas/io/formats/style.py?line=1465'>1466</a>     )
# -> <a href='file:///c%3A/Users/lucaguarda/Anaconda3/lib/site-packages/pandas/io/formats/style.py?line=1466'>1467</a> self._update_ctx(result)
#    <a href='file:///c%3A/Users/lucaguarda/Anaconda3/lib/site-packages/pandas/io/formats/style.py?line=1467'>1468</a> return self
#
# File c:\Users\lucaguarda\Anaconda3\lib\site-packages\pandas\io\formats\style.py:1283, in Styler._update_ctx(self, attrs)
#    <a href='file:///c%3A/Users/lucaguarda/Anaconda3/lib/site-packages/pandas/io/formats/style.py?line=1269'>1270</a> """
#    <a href='file:///c%3A/Users/lucaguarda/Anaconda3/lib/site-packages/pandas/io/formats/style.py?line=1270'>1271</a> Update the state of the ``Styler`` for data cells.
#    <a href='file:///c%3A/Users/lucaguarda/Anaconda3/lib/site-packages/pandas/io/formats/style.py?line=1271'>1272</a>
#    (...)
#    <a href='file:///c%3A/Users/lucaguarda/Anaconda3/lib/site-packages/pandas/io/formats/style.py?line=1279'>1280</a>     matter.
#    <a href='file:///c%3A/Users/lucaguarda/Anaconda3/lib/site-packages/pandas/io/formats/style.py?line=1280'>1281</a> """
#    <a href='file:///c%3A/Users/lucaguarda/Anaconda3/lib/site-packages/pandas/io/formats/style.py?line=1281'>1282</a> if not self.index.is_unique or not self.columns.is_unique:
# -> <a href='file:///c%3A/Users/lucaguarda/Anaconda3/lib/site-packages/pandas/io/formats/style.py?line=1282'>1283</a>     raise KeyError(
#    <a href='file:///c%3A/Users/lucaguarda/Anaconda3/lib/site-packages/pandas/io/formats/style.py?line=1283'>1284</a>         "`Styler.apply` and `.applymap` are not compatible "
#    <a href='file:///c%3A/Users/lucaguarda/Anaconda3/lib/site-packages/pandas/io/formats/style.py?line=1284'>1285</a>         "with non-unique index or columns."
#    <a href='file:///c%3A/Users/lucaguarda/Anaconda3/lib/site-packages/pandas/io/formats/style.py?line=1285'>1286</a>     )
#    <a href='file:///c%3A/Users/lucaguarda/Anaconda3/lib/site-packages/pandas/io/formats/style.py?line=1287'>1288</a> for cn in attrs.columns:
#    <a href='file:///c%3A/Users/lucaguarda/Anaconda3/lib/site-packages/pandas/io/formats/style.py?line=1288'>1289</a>     j = self.columns.get_loc(cn)
#
# KeyError: '`Styler.apply` and `.applymap` are not compatible with non-unique index or columns.'
